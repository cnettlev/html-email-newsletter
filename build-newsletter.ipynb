# %%
import csv
from datetime import datetime
from categorized_info import categorized_info
from utils import downloadFiles

# Define constants

DATE_FORMAT = "%d/%m/%Y %H:%M:%S"
DATE_FROM = "01/01/2023 00:00:00"  # Change this date as needed

TOP_BANNER = "https://innovacionyrobotica.com/newsletter_red-inv-robotica/banner_1-min.png"
BOTTOM_BANNER = "https://innovacionyrobotica.com/newsletter_red-inv-robotica/banner_2-min.png"
DEFAULT_IMG = "https://innovacionyrobotica.com/newsletter_red-inv-robotica/single-robot_0-min.png"
DEFAULT_IMG_ADDRESS = 'https://innovacionyrobotica.com/newsletter_red-inv-robotica/'
NUMERO_BOLETIN = "4"

BACKGROUND_COLOR = "#fff"# "#6198d7"
TEXT_COLOR = "#000"

# Load CSV data
news_data = []
with open('Información para el canal de investigadores (Respuestas) - Respuestas de formulario 1.csv', 'r') as csv_file:
    csv_reader = csv.DictReader(csv_file)
    for row in csv_reader:
        news_data.append(row)

# %%
# Categorize news
categorized_news = {section: [] for section in [
    "Avances tecnológicos y proyectos destacados",
    "Propuesta para entrevista",
    "Eventos y conferencias",
    "Recursos educativos",
    "Oportunidades de financiamiento",
    "Propuesta de colaboración",
    "Noticias y tendencias",
    "Otros"
]}

for news in news_data:
    news_date = datetime.strptime(news['Marca temporal'], DATE_FORMAT)
    if news_date >= datetime.strptime(DATE_FROM, DATE_FORMAT):
        section = news.get('El contenido que deseas compartir es', 'Otros')
        if not (section in categorized_news.keys()):
            section = 'Otros'
        news.Extra = downloadFiles(news[categorized_info[section]['Extra']].split(','))

        for urlInfo in categorized_info[section]['More']:
            news.Extra['url'].append(news[urlInfo])
            
        categorized_news[section].append(news)
        
        # downloadFiles(news)
# Out:
# b'' b'--2023-09-04 05:18:22--  https://drive.google.com/uc?export=download&id=1WrddVFkViiY0lkFLNo27dCO30c8LQ9wi\nResolving drive.google.com (drive.google.com)... 2800:3f0:4003:c03::71, 2800:3f0:4003:c03::65, 2800:3f0:4003:c03::66, ...\nConnecting to drive.google.com (drive.google.com)|2800:3f0:4003:c03::71|:443... connected.\nHTTP request sent, awaiting response... 303 See Other\nLocation: https://doc-0k-10-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/jlnpfnpml20b33solccf1tb9nuuhkvhv/1693815450000/12305694467948548888/*/1WrddVFkViiY0lkFLNo27dCO30c8LQ9wi?e=download&uuid=92c459d1-4c8f-44e1-ad6b-e48ff630be9e [following]\nWarning: wildcards not supported in HTTP.\n--2023-09-04 05:18:23--  https://doc-0k-10-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/jlnpfnpml20b33solccf1tb9nuuhkvhv/1693815450000/12305694467948548888/*/1WrddVFkViiY0lkFLNo27dCO30c8LQ9wi?e=download&uuid=92c459d1-4c8f-44e1-ad6b-e48ff630be9e\nResolving doc-0k-10-docs.googleusercontent.com (doc-0k-10-docs.googleusercontent.com)... 2800:3f0:4003:c03::84, 142.250.0.132\nConnecting to doc-0k-10-docs.googleusercontent.com (doc-0k-10-docs.googleusercontent.com)|2800:3f0:4003:c03::84|:443... connected.\nHTTP request sent, awaiting response... 200 OK\nLength: 27701 (27K) [image/jpeg]\nSaving to: \xe2\x80\x98./images/boletin.jpg\xe2\x80\x99\n\n     0K .......... .......... .......                         100% 1,06M=0,03s\n\n2023-09-04 05:18:23 (1,06 MB/s) - \xe2\x80\x98./images/boletin.jpg\xe2\x80\x99 saved [27701/27701]\n\n'
# b'' b'--2023-09-04 05:18:26--  https://drive.google.com/uc?export=download&id=1tyhgqR4ycMOPN9MymmXaTDpp7oOYFeNK\nResolving drive.google.com (drive.google.com)... 2800:3f0:4003:c03::71, 2800:3f0:4003:c03::65, 2800:3f0:4003:c03::66, ...\nConnecting to drive.google.com (drive.google.com)|2800:3f0:4003:c03::71|:443... connected.\nHTTP request sent, awaiting response... 303 See Other\nLocation: https://doc-00-10-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/qhiuqbun6sbtmru70r3nmb96237n7vin/1693815450000/12305694467948548888/*/1tyhgqR4ycMOPN9MymmXaTDpp7oOYFeNK?e=download&uuid=f684ea5b-4e6d-4f01-bfb8-47833135d0f8 [following]\nWarning: wildcards not supported in HTTP.\n--2023-09-04 05:18:27--  https://doc-00-10-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/qhiuqbun6sbtmru70r3nmb96237n7vin/1693815450000/12305694467948548888/*/1tyhgqR4ycMOPN9MymmXaTDpp7oOYFeNK?e=download&uuid=f684ea5b-4e6d-4f01-bfb8-47833135d0f8\nResolving doc-00-10-docs.googleusercontent.com (doc-00-10-docs.googleusercontent.com)... 2800:3f0:4003:c03::84, 142.250.0.132\nConnecting to doc-00-10-docs.googleusercontent.com (doc-00-10-docs.googleusercontent.com)|2800:3f0:4003:c03::84|:443... connected.\nHTTP request sent, awaiting response... 200 OK\nLength: 136465 (133K) [image/jpeg]\nSaving to: \xe2\x80\x98./images/boletin_nombre.jpg\xe2\x80\x99\n\n     0K .......... .......... .......... .......... .......... 37% 1,30M 0s\n    50K .......... .......... .......... .......... .......... 75% 2,33M 0s\n   100K .......... .......... .......... ...                  100% 5,92M=0,06s\n\n2023-09-04 05:18:28 (2,03 MB/s) - \xe2\x80\x98./images/boletin_nombre.jpg\xe2\x80\x99 saved [136465/136465]\n\n'
# b'' b'--2023-09-04 05:18:31--  https://drive.google.com/uc?export=download&id=10VJqES2Y_kfBmrNA14K27yzv_B-ZmY2P\nResolving drive.google.com (drive.google.com)... 2800:3f0:4003:c03::71, 2800:3f0:4003:c03::65, 2800:3f0:4003:c03::66, ...\nConnecting to drive.google.com (drive.google.com)|2800:3f0:4003:c03::71|:443... connected.\nHTTP request sent, awaiting response... 303 See Other\nLocation: https://doc-00-10-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/sbiue8v8mucjui16evldbt392vtlq07g/1693815450000/12305694467948548888/*/10VJqES2Y_kfBmrNA14K27yzv_B-ZmY2P?e=download&uuid=7790761f-09af-4507-9fea-1cbdec989f7b [following]\nWarning: wildcards not supported in HTTP.\n--2023-09-04 05:18:32--  https://doc-00-10-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/sbiue8v8mucjui16evldbt392vtlq07g/1693815450000/12305694467948548888/*/10VJqES2Y_kfBmrNA14K27yzv_B-ZmY2P?e=download&uuid=7790761f-09af-4507-9fea-1cbdec989f7b\nResolving doc-00-10-docs.googleusercontent.com (doc-00-10-docs.googleusercontent.com)... 2800:3f0:4003:c03::84, 142.250.0.132\nConnecting to doc-00-10-docs.googleusercontent.com (doc-00-10-docs.googleusercontent.com)|2800:3f0:4003:c03::84|:443... connected.\nHTTP request sent, awaiting response... 200 OK\nLength: 192558 (188K) [image/jpeg]\nSaving to: \xe2\x80\x98./images/boletin_talk.jpg\xe2\x80\x99\n\n     0K .......... .......... .......... .......... .......... 26% 1,93M 0s\n    50K .......... .......... .......... .......... .......... 53% 1,38M 0s\n   100K .......... .......... .......... .......... .......... 79% 7,41M 0s\n   150K .......... .......... .......... ........             100% 2,06M=0,09s\n\n2023-09-04 05:18:32 (2,15 MB/s) - \xe2\x80\x98./images/boletin_talk.jpg\xe2\x80\x99 saved [192558/192558]\n\n'
# b'' b'--2023-09-04 05:18:34--  https://drive.google.com/uc?export=download&id=1e_LmKs7vIe8X310gt8YaVlszHNo1Rcnp\nResolving drive.google.com (drive.google.com)... 2800:3f0:4003:c03::71, 2800:3f0:4003:c03::65, 2800:3f0:4003:c03::66, ...\nConnecting to drive.google.com (drive.google.com)|2800:3f0:4003:c03::71|:443... connected.\nHTTP request sent, awaiting response... 303 See Other\nLocation: https://doc-0o-10-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/1gpqin9ur3v62195spjmo6v53leadet4/1693815450000/12305694467948548888/*/1e_LmKs7vIe8X310gt8YaVlszHNo1Rcnp?e=download&uuid=e40b2a2d-d27c-42f6-8c8d-93ea007958d1 [following]\nWarning: wildcards not supported in HTTP.\n--2023-09-04 05:18:35--  https://doc-0o-10-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/1gpqin9ur3v62195spjmo6v53leadet4/1693815450000/12305694467948548888/*/1e_LmKs7vIe8X310gt8YaVlszHNo1Rcnp?e=download&uuid=e40b2a2d-d27c-42f6-8c8d-93ea007958d1\nResolving doc-0o-10-docs.googleusercontent.com (doc-0o-10-docs.googleusercontent.com)... 2800:3f0:4003:c03::84, 142.250.0.132\nConnecting to doc-0o-10-docs.googleusercontent.com (doc-0o-10-docs.googleusercontent.com)|2800:3f0:4003:c03::84|:443... connected.\nHTTP request sent, awaiting response... 200 OK\nLength: 192398 (188K) [application/pdf]\nSaving to: \xe2\x80\x98./att/[RoboticsMeetUp2023] Invitacion a Local Chairs.pdf\xe2\x80\x99\n\n     0K .......... .......... .......... .......... .......... 26% 1,24M 0s\n    50K .......... .......... .......... .......... .......... 53% 2,27M 0s\n   100K .......... .......... .......... .......... .......... 79% 2,63M 0s\n   150K .......... .......... .......... .......              100% 6,67M=0,08s\n\n2023-09-04 05:18:35 (2,16 MB/s) - \xe2\x80\x98./att/[RoboticsMeetUp2023] Invitacion a Local Chairs.pdf\xe2\x80\x99 saved [192398/192398]\n\n'
# b'' b'--2023-09-04 05:18:36--  https://drive.google.com/uc?export=download&id=1TySVWw_m1FXPsf2X4_nKJwb39u1jSiKc\nResolving drive.google.com (drive.google.com)... 2800:3f0:4003:c03::71, 2800:3f0:4003:c03::65, 2800:3f0:4003:c03::66, ...\nConnecting to drive.google.com (drive.google.com)|2800:3f0:4003:c03::71|:443... connected.\nHTTP request sent, awaiting response... 303 See Other\nLocation: https://doc-14-10-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/l0qpg4hh3q8t88ogqtbhp15r2algj7me/1693815450000/12305694467948548888/*/1TySVWw_m1FXPsf2X4_nKJwb39u1jSiKc?e=download&uuid=26a808c7-82ef-4a97-8227-2b27e5fcdf66 [following]\nWarning: wildcards not supported in HTTP.\n--2023-09-04 05:18:37--  https://doc-14-10-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/l0qpg4hh3q8t88ogqtbhp15r2algj7me/1693815450000/12305694467948548888/*/1TySVWw_m1FXPsf2X4_nKJwb39u1jSiKc?e=download&uuid=26a808c7-82ef-4a97-8227-2b27e5fcdf66\nResolving doc-14-10-docs.googleusercontent.com (doc-14-10-docs.googleusercontent.com)... 2800:3f0:4003:c03::84, 142.250.0.132\nConnecting to doc-14-10-docs.googleusercontent.com (doc-14-10-docs.googleusercontent.com)|2800:3f0:4003:c03::84|:443... connected.\nHTTP request sent, awaiting response... 200 OK\nLength: 144915 (142K) [image/png]\nSaving to: \xe2\x80\x98./images/boletin_startup-ciencia-2024-min.png\xe2\x80\x99\n\n     0K .......... .......... .......... .......... .......... 35% 1,72M 0s\n    50K .......... .......... .......... .......... .......... 70% 3,74M 0s\n   100K .......... .......... .......... .......... .         100% 3,03M=0,05s\n\n2023-09-04 05:18:37 (2,52 MB/s) - \xe2\x80\x98./images/boletin_startup-ciencia-2024-min.png\xe2\x80\x99 saved [144915/144915]\n\n'
# b'' b'--2023-09-04 05:18:38--  https://drive.google.com/uc?export=download&id=1EC7aIDosCy3iThsadHZ2gLfihjQxrrYi\nResolving drive.google.com (drive.google.com)... 2800:3f0:4003:c03::71, 2800:3f0:4003:c03::65, 2800:3f0:4003:c03::66, ...\nConnecting to drive.google.com (drive.google.com)|2800:3f0:4003:c03::71|:443... connected.\nHTTP request sent, awaiting response... 303 See Other\nLocation: https://doc-14-10-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/1hp2psn2mn7h1uhfvfti8q5o3690o4iq/1693815450000/12305694467948548888/*/1EC7aIDosCy3iThsadHZ2gLfihjQxrrYi?e=download&uuid=ed01961e-62b6-471c-af66-a74513b04593 [following]\nWarning: wildcards not supported in HTTP.\n--2023-09-04 05:18:39--  https://doc-14-10-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/1hp2psn2mn7h1uhfvfti8q5o3690o4iq/1693815450000/12305694467948548888/*/1EC7aIDosCy3iThsadHZ2gLfihjQxrrYi?e=download&uuid=ed01961e-62b6-471c-af66-a74513b04593\nResolving doc-14-10-docs.googleusercontent.com (doc-14-10-docs.googleusercontent.com)... 2800:3f0:4003:c03::84, 142.250.0.132\nConnecting to doc-14-10-docs.googleusercontent.com (doc-14-10-docs.googleusercontent.com)|2800:3f0:4003:c03::84|:443... connected.\nHTTP request sent, awaiting response... 200 OK\nLength: 61667 (60K) [image/png]\nSaving to: \xe2\x80\x98./images/boletin_apoyo-milenios.png\xe2\x80\x99\n\n     0K .......... .......... .......... .......... .......... 83%  844K 0s\n    50K ..........                                            100% 44,9M=0,06s\n\n2023-09-04 05:18:40 (1013 KB/s) - \xe2\x80\x98./images/boletin_apoyo-milenios.png\xe2\x80\x99 saved [61667/61667]\n\n'
# b'' b'--2023-09-04 05:18:41--  https://drive.google.com/uc?export=download&id=1P2_QY3TlVJtf8K3pA6H5HCicZKDCRdLC\nResolving drive.google.com (drive.google.com)... 2800:3f0:4003:c03::71, 2800:3f0:4003:c03::65, 2800:3f0:4003:c03::66, ...\nConnecting to drive.google.com (drive.google.com)|2800:3f0:4003:c03::71|:443... connected.\nHTTP request sent, awaiting response... 303 See Other\nLocation: https://doc-0c-10-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/ug1gu6p84aqbn469sg2fh4n7sc08ghni/1693815450000/12305694467948548888/*/1P2_QY3TlVJtf8K3pA6H5HCicZKDCRdLC?e=download&uuid=8a3f2e59-1e02-4970-9fc6-53f315c47af8 [following]\nWarning: wildcards not supported in HTTP.\n--2023-09-04 05:18:41--  https://doc-0c-10-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/ug1gu6p84aqbn469sg2fh4n7sc08ghni/1693815450000/12305694467948548888/*/1P2_QY3TlVJtf8K3pA6H5HCicZKDCRdLC?e=download&uuid=8a3f2e59-1e02-4970-9fc6-53f315c47af8\nResolving doc-0c-10-docs.googleusercontent.com (doc-0c-10-docs.googleusercontent.com)... 2800:3f0:4003:c03::84, 142.250.0.132\nConnecting to doc-0c-10-docs.googleusercontent.com (doc-0c-10-docs.googleusercontent.com)|2800:3f0:4003:c03::84|:443... connected.\nHTTP request sent, awaiting response... 200 OK\nLength: 33602 (33K) [image/png]\nSaving to: \xe2\x80\x98./images/boletin-IDeA-ID-min.png\xe2\x80\x99\n\n     0K .......... .......... .......... ..                   100% 1,48M=0,02s\n\n2023-09-04 05:18:42 (1,48 MB/s) - \xe2\x80\x98./images/boletin-IDeA-ID-min.png\xe2\x80\x99 saved [33602/33602]\n\n'
# b'' b'--2023-09-04 05:18:43--  https://drive.google.com/uc?export=download&id=1bI3CFvZwWp5vctf5zwMR9d_CZrfyDQnC\nResolving drive.google.com (drive.google.com)... 2800:3f0:4003:c03::71, 2800:3f0:4003:c03::65, 2800:3f0:4003:c03::66, ...\nConnecting to drive.google.com (drive.google.com)|2800:3f0:4003:c03::71|:443... connected.\nHTTP request sent, awaiting response... 303 See Other\nLocation: https://doc-10-10-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/b86juuv2cq6ebmk9mecven2t2ipc79hk/1693815450000/12305694467948548888/*/1bI3CFvZwWp5vctf5zwMR9d_CZrfyDQnC?e=download&uuid=e6c9f47c-515c-4558-a441-145c37c72ef7 [following]\nWarning: wildcards not supported in HTTP.\n--2023-09-04 05:18:43--  https://doc-10-10-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/b86juuv2cq6ebmk9mecven2t2ipc79hk/1693815450000/12305694467948548888/*/1bI3CFvZwWp5vctf5zwMR9d_CZrfyDQnC?e=download&uuid=e6c9f47c-515c-4558-a441-145c37c72ef7\nResolving doc-10-10-docs.googleusercontent.com (doc-10-10-docs.googleusercontent.com)... 2800:3f0:4003:c03::84, 142.250.0.132\nConnecting to doc-10-10-docs.googleusercontent.com (doc-10-10-docs.googleusercontent.com)|2800:3f0:4003:c03::84|:443... connected.\nHTTP request sent, awaiting response... 200 OK\nLength: 50826 (50K) [image/png]\nSaving to: \xe2\x80\x98./images/boletin_anid-min.png\xe2\x80\x99\n\n     0K .......... .......... .......... .......... ......... 100% 1,40M=0,03s\n\n2023-09-04 05:18:44 (1,40 MB/s) - \xe2\x80\x98./images/boletin_anid-min.png\xe2\x80\x99 saved [50826/50826]\n\n'

# %%
import json

with open('preprocessed.json','w') as f:
    f.write(json.dumps(categorized_news))

# %%
with open('preprocessed.json', 'r') as read_file:
    categorized_news = json.loads(read_file.read())

# %%
categorized_news['Propuesta de colaboración'][0].Extra['image'] = ['boletin-rmeetup-min.jpg']

# %%
# Generate HTML
with open('newsletter.html', 'w') as html_file:
    html_content = f'''<!DOCTYPE html>
                        <html lang="en">
                        <head>
                            <!-- Add your head content here -->
                            <meta charset="UTF-8">
                            <meta name="viewport" content="width=device-width, initial-scale=1.0">
                            <title>Boletín mensual #{NUMERO_BOLETIN}</title>
                            <style>
                                body {{
                                    margin: 0;
                                    padding: 0;
                                    font-family: 'Roboto', Arial, sans-serif;
                                    background-color: #000;
                                    color: #fff;
                                }}
                            </style>
                            <link href="https://fonts.googleapis.com/css2?family=Roboto:wght@400&display=swap" rel="stylesheet">
                        </head>
                        <body style="margin: 0; padding: 0; font-family: 'Roboto', Arial, sans-serif; background-color: {BACKGROUND_COLOR}; color: #fff;">

                            <!-- Top Banner -->
                            <div style=" position: relative; text-align: center; color: #000;">
                                <img src="{TOP_BANNER}" alt="Top Banner" style="max-width: 100%;">
                                <h1 style="line-height: 1.1; position: absolute; top: 50%; left: 20%; transform: translate(-50%, -50%); text-align: left; margin: 10px;">BOLETÍN<br>MENSUAL #{NUMERO_BOLETIN}</h1>
                            </div>
                    '''

    for section, news_list in categorized_news.items(): #filtered_news.items():
        if news_list:
#             html_content += f'''
#             <div class="section">
#                 <h2>{section}</h2>
#                 <div style="display: flex;">
#             '''

            html_content += f'''
            <div style="padding: 0px 20px; background-color: {BACKGROUND_COLOR};">
                <h2 style="font-size: 24px;background-color: {BACKGROUND_COLOR}; margin: 10px;">{section}</h2>
                <div style="display: flex;">'''
#                <div style="display: flex; flex-wrap: wrap; gap: 20px;">
#            '''

            for news_i, news in enumerate(news_list):
#                num_columns = 2 if len(news_list) > 1 else 1
#                column_width = f'width: {100 / num_columns}%;' if num_columns == 2 else 'width: 100%;'
#                html_content += f'''
#                    <div class="column" style="{column_width}">
#                        <img src=f"{news.get('Image URL',DEFAULT_IMG)}" alt="{news['Title']}" style="max-width: 100%; height: auto; margin-bottom: 10px;">
#                        <p>{news['Content']}</p>
#                    </div>
#                '''

                if (news_i > 0) and (news_i % 2 == 0):
                    html_content += f'''
                        </div>
                        <div style="display: flex;">'''
#                        <div style="display: flex; flex-wrap: wrap; gap: 20px;">
#                    '''                    

#                html_content += f'''
#                    <div style="flex: 1;">
                
                if news_i == len(news_list) - 1 and (news_i % 2 == 0):
                    html_content += f'''
                        <div style="flex:50%;">
                            <h3 style="font-size: 12px; margin-bottom: 2px; text-align: justify;">{news[categorized_info[section]['Title']]}</h3>
                            <img src="{DEFAULT_IMG_ADDRESS+news.Extra.get('image')[0] if len(news.Extra['image'])>0 else DEFAULT_IMG}" alt="Imagen de la noticia {news_i}" style="width: 90%; max-width: 90%; height: auto; margin-bottom: 10px; border: 5px solid;
    border-color: {TEXT_COLOR};">
                        </div>
                        <div style="flex:50%;">
                        '''
                else:
                    html_content += f'''
                        <div style="flex:50%;">
                            <img src="{DEFAULT_IMG_ADDRESS+news.Extra.get('image')[0] if len(news.Extra['image'])>0 else DEFAULT_IMG}" alt="Imagen de la noticia {news_i}" style="width: 90%; max-width: 90%; height: auto; border: 5px solid;
    border-color: {TEXT_COLOR};">
                        <h3 style="font-size: 12px; margin-bottom: 2px; text-align: justify; padding: 0px 5px;">{news[categorized_info[section]['Title']]}</h3>
                        '''
                    

                html_content += f'''<div style="padding: 0px 5px;">'''

                for content in categorized_info[section]['Content']:
                    if news[content]:
                        to_be_introduced = news[content].replace("\n","<br />\n")
                        html_content += f'''<p style="font-size: 12px; line-height: 1.5; text-align: justify; ">{to_be_introduced}</p>'''
                
                for url in news.Extra['url']:
                    html_content += f'''<p style="font-size: 12px; line-height: 1.5; text-align: justify; ">Más información <a href="{url}">aquí</a>.</p>'''
                
                for i, url in enumerate(news.Extra['drive-url']):
                    if i == 0:
                        html_content += f'''<p style="font-size: 12px; line-height: 1.5; text-align: justify; ">Archivo{"s" if len(news.Extra['drive-url'])>1 else ""} <a href="{url}">aquí</a>'''
                    else:
                        if i == len(news.Extra['drive-url']) - 1 :
                            html_content += f''' y <a href="{url}">aquí</a>'''
                        else:
                            html_content += f''', <a href="{url}">aquí</a>'''
                    if i == len(news.Extra['drive-url']) - 1 :
                        html_content += ".</p>"

                html_content += f'''</div>'''

                html_content += f'''
                    </div>
                    '''

            html_content += '''
                </div>
            </div>
            '''

    html_content += f'''<!-- Bottom Banner -->
                        <div style=" position: relative; text-align: center; color: #000;"> 
                            <img src="{BOTTOM_BANNER}" alt="Bottom Banner" style="max-width: 100%;">
                            <p style="font-size: 10px; position: absolute; top: 20%; left: 30%; transform: translate(-50%, -50%); text-align: left;">Si deseas añadir algo al próximo boletín ingrésalo <a href="https://docs.google.com/forms/d/e/1FAIpQLSeieiKq4-b_aAnlh9B7cPQSLzsnvkgUTP9uQaMiwi3XOnQ2XA/viewform">aquí</a>.</p>
                        </div>
                        </body>
                        </html>'''

    html_file.write(html_content)

print("HTML file 'newsletter.html' has been generated.")
# Out:
# HTML file 'newsletter.html' has been generated.
